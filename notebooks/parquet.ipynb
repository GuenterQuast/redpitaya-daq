# %%
import pandas as pd
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import tarfile
import io

import os
import sys

notebook_path = os.path.abspath('')
project_root = os.path.dirname(notebook_path)
sys.path.append(project_root)


from helpers.read_tar_parquet_to_df import process_parquet_files_from_tar

# %%
path="../measurements/coincidence/"
# Path to your tar file
tar_path = path+'2024-07-01_1559/spectrum.tar'



def work_on_df(data_frame):
    data_frame.plot()
    plt.show()

process_parquet_files_from_tar(tar_path,work_on_df,10,0)
# Out:
# 7
# Processing spectrum_2424.parquet
# Processing spectrum_4144.parquet
# Processing spectrum_6248.parquet
# Processing spectrum_8496.parquet
# Processing spectrum_9035.parquet
# Processing spectrum_12354.parquet
# Processing spectrum_15372.parquet
