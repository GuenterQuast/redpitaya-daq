# %%
import pandas as pd
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import tarfile
import io

import os
import sys

notebook_path = os.path.abspath('')
project_root = os.path.dirname(notebook_path)
sys.path.append(project_root)


from helpers.read_tar_parquet_to_df import process_parquet_files_from_tar

# %%
# Path to your tar file
tar_path = '../target/2024-07-01_1451/spectrum.tar'



def work_on_df(data_frame):
    print(data_frame['ch2'].max())
    data_frame.plot()
    plt.show()

process_parquet_files_from_tar(tar_path,work_on_df,10)
# Out:
# Processing spectrum_8.parquet
# 861
# Processing spectrum_19.parquet
# 487
# Processing spectrum_21.parquet
# 229
# Processing spectrum_51.parquet
# 4095
# Processing spectrum_66.parquet
# 526
# Processing spectrum_73.parquet
# 4095
# Processing spectrum_75.parquet
# 4095
# Processing spectrum_95.parquet
# 4095
# Processing spectrum_105.parquet
# 1555
# Processing spectrum_113.parquet
# 998
